# %%
import matplotlib.pyplot as plt
from numpy import loadtxt

# %%
import csv
data = []
with open('received_data.dat', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')
    for row in spamreader:
        for point in row:
            data.append(float(point))
        # print(float(row[100]))
        # print("1")
        # # print(row)

# %%
plt.plot(range(len(data)), data)
plt.title("Number of traffic response by the server")
plt.xlabel("time (second)")
plt.ylabel("traffic (kB/s)")
plt.show()

# %%
a = [103 ,
85 ,
67 ,
48 ,
42 ,
42 ,
38 ,
50 ,
68 ,
85 ,
99 ,
113 ,
126 ,
127 ,
130 ,
138 ,
126 ,
130 ,
130 ,
152 ,
179 ,
185 ,
168 ,
153 ,
103 ,
85 ,
59 ,
50 ,
43 ,
41 ,
39 ,
52 ,
70 ,
84 ,
99 ,
110 ,
122 ,
126 ,
128 ,
136 ,
134 ,
130 ,
124 ,
156 ,
184 ,
187 ,
182 ,
161 ,
84 ,
61 ,
46 ,
36 ,
34 ,
31 ,
30 ,
40 ,
51 ,
67 ,
78 ,
85 ,
91 ,
97 ,
94 ,
101 ,
94 ,
95 ,
100 ,
115 ,
136 ,
137 ,
138 ,
119 ,
116 ,
90 ,
69 ,
59 ,
50 ,
45 ,
43 ,
58 ,
76 ,
96 ,
110 ,
121 ,
138 ,
146 ,
148 ,
149 ,
154 ,
145 ,
136 ,
175 ,
201 ,
207 ,
203 ,
184 ,
105 ,
85 ,
61 ,
51 ,
42 ,
44 ,
41 ,
54 ,
71 ,
87 ,
103 ,
119 ,
122 ,
127 ,
128 ,
137 ,
134 ,
133 ,
121 ,
153 ,
181 ,
183 ,
170 ,
167 ,
122 ,
99 ,
75 ,
56 ,
49 ,
47 ,
45 ,
62 ,
78 ,
91 ,
114 ,
121 ,
136 ,
140 ,
142 ,
146 ,
154 ,
136 ,
141 ,
172 ,
204 ,
204 ,
195 ,
177 ,
87 ,
71 ,
53 ,
40 ,
37 ,
37 ,
34 ,
45 ,
61 ,
74 ,
81 ,
98 ,
107 ,
108 ,
112 ,
116 ,
112 ,
116 ,
110 ,
127 ,
160 ,
166 ,
146 ,
140]

# %%
plt.plot(range(len(a)), a)
plt.title("Number of request generated automatically")
plt.xlabel("time (minute)")
plt.ylabel("number of requests")
plt.show()

# %%
import csv
data_search = []
with open('search_data.dat', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')
    for row in spamreader:
        for point in row:
            data_search.append(float(point))
        # print(float(row[100]))
        # print("1")
        # # print(row)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-ecffb98f7e1a> in <module>
#       5     for row in spamreader:
#       6         for point in row:
# ----> 7             data_search.append(float(point))
#       8         # print(float(row[100]))
#       9         # print("1")
#
# ValueError: could not convert string to float: ''
